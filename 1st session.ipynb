# %%
x = 5
print(x)
type(x)
# Out:
# 5
# int

# %%
a = 3.5
print(a)
type(a)
# Out:
# 3.5
# float

# %%
x = True
y = False
print(x,y)
type(x)
# Out:
# True False
# bool

# %%
a = 'you?'
print('where are',a)
type(a)
# Out:
# where are you?
# str

# %%
a = 5+7j
print(a)
print(a.real,a.imag)
type(a)
# Out:
# (5+7j)
# 5.0 7.0
# complex

# %%
he = 6
her = 8
print(he)
he = her+2
print(he)
'heher'
# Out:
# 6
# 10
# 'heher'

# %%
x = 8
if x < 8:
    print('excess')
elif x > 2:
    print('true')
else:
    print('false')
# Out:
# true

# %%
a = ['h','i','j']
print(a)
a.append('k')
print(a)
a.insert(3,'d')
b = a
print(b)
type(b)
# Out:
# ['h', 'i', 'j']
# ['h', 'i', 'j', 'k']
# ['h', 'i', 'j', 'd', 'k']
# list

# %%
#sum of numbers in the list
x = [2,4,6,4,5,3]
sum = 0
for i in x:
  sum = sum + i
print('total =',sum )
# Out:
# total = 24

# %%
#add natural numbers
n = int(input('enter value ='))
sum = 0
v = 1
while v <= n:
  sum = sum + v
  v = v + 1
print('the value =',sum)
# Out:
# enter value =25
# the value = 325

# %%
print(list(range(2, 100, 15)))
# Out:
# [2, 17, 32, 47, 62, 77, 92]

# %%
for vz in "howryou":
  if vz == "r":
    break
  print(vz)
print('done')
# Out:
# h
# o
# w
# done

# %%
for va in "didudoso":
  if va == "o":
    continue
  print(va)
print('finished')
# Out:
# d
# i
# d
# u
# d
# s
# finished
